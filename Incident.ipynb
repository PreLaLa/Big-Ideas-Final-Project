# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
Squirrel_Hill_North = 0
Shadyside = 0
Bedford_Dwellings = 0
Lincoln_Lemington_Belmar = 0
Lower_Lawrenceville = 0
Central_Lawrenceville = 0
Golden_Triangle_Civic_Arena = 0
Carrick = 0
Highland_Park = 0
South_Side_Flats = 0
Middle_Hill = 0
North_Oakland = 0
Bloomfield = 0
Outside_City = 0
East_Hills = 0
Knoxville = 0
Point_Breeze = 0
Central_Oakland = 0
Brighton_Heights = 0
Point_Breeze_North = 0
Homewood_North = 0
Regent_Square = 0
Homewood_West = 0
Homewood_South = 0
Perry_North = 0
West_Oakland = 0
Hazelwood = 0
St_Clair = 0
Northview_Heights = 0
Oakwood = 0
Arlington = 0
North_Shore = 0
Westwood = 0
Upper_Hill = 0
Polish_Hill = 0
Crawford_Roberts=0
Lincoln_Place = 0
Allegheny_West = 0
Larimer = 0
Glen_Hazel = 0
Bon_Air = 0
Arlington_Heights = 0
Allentown = 0
New_Homestead = 0
Hays = 0
Central_Northside = 0
Stanton_Heights = 0
Allegheny_Center = 0
Friendship = 0
East_Carnegie = 0
Fairywood = 0
Windgap = 0
Squirrel_Hill_South = 0
Mt_Oliver_Neighborhood = 0
Marshall_Shadeland = 0
Mount_Washington = 0
Summer_Hill = 0
Swisshelm_Park = 0
Ridgemont = 0
Outside_State = 0
Outside_County = 0
Crafton_Heights = 0
Troy_Hill_Herrs_Island = 0
Beechview = 0
Morningside = 0
California_Kirkbride = 0
Greenfield = 0
Bluff = 0
East_Liberty = 0
Elliott = 0
East_Allegheny = 0
Beltzhoover = 0
Upper_Lawrenceville = 0
Sheraden = 0
Perry_South = 0
Manchester = 0
Strip_District = 0
Banksville = 0
Garfield = 0
Brookline = 0
South_Side_Slopes = 0
South_Oakland = 0
Spring_Hill_City_View = 0
Terrace_Village = 0
South_Shore = 0
Chateau = 0
Duquesne_Heights = 0
Overbrook = 0
Spring_Garden = 0
West_End = 0
Fineview = 0
Chartiers_City = 0
Esplen = 0
Mt_Oliver_Boro = 0
blank = 0
with open('C:\\Users\\prest\\Intro-to-Jupyter\\Final-Project\\apb.csv', mode = 'r') as csvfile:
    file = csv.DictReader(csvfile)
    for row in file:
        neighborhood = row['INCIDENTNEIGHBORHOOD']
        if neighborhood == "Squirrel Hill North":
            Squirrel_Hill_North += 1
        if neighborhood == "Shadyside":
            Shadyside += 1
        if neighborhood == "Bedford Dwellings":
            Bedford_Dwellings += 1
        if neighborhood == "Lincoln-Lemington-Belmar":
            Lincoln_Lemington_Belmar += 1
        if neighborhood == "Lower Lawrenceville":
            Lower_Lawrenceville += 1
        if neighborhood == "Central Lawrenceville":
            Central_Lawrenceville += 1
        if neighborhood == "Golden Triangle/Civic Arena":
            Golden_Triangle_Civic_Arena += 1
        if neighborhood == "Carrick":
            Carrick += 1
        if neighborhood == "Highland Park":
            Highland_Park += 1
        if neighborhood == "South Side Flats":
            South_Side_Flats += 1
        if neighborhood == "Middle Hill":
            Middle_Hill += 1
        if neighborhood == "North Oakland":
            North_Oakland += 1
        if neighborhood == "Bloomfield":
            Bloomfield += 1
        if neighborhood == "Outside City":
            Outside_City += 1
        if neighborhood == "East Hills":
            East_Hills += 1
        if neighborhood == "Knoxville":
            Knoxville += 1
        if neighborhood == "Point Breeze":
            Point_Breeze += 1
        if neighborhood == "Central Oakland":
            Central_Oakland += 1
        if neighborhood == "Brighton Heights":
            Brighton_Heights += 1
        if neighborhood == "Point Breeze North":
            Point_Breeze_North += 1
        if neighborhood == "Homewood North":
            Homewood_North += 1
        if neighborhood == "Regent Square":
            Regent_Square += 1
        if neighborhood == "Homewood West":
            Homewood_West += 1
        if neighborhood == "Homewood South":
            Homewood_South += 1
        if neighborhood == "Perry North":
            Perry_North += 1
        if neighborhood == "West Oakland":
            West_Oakland += 1
        if neighborhood == "Hazelwood":
            Hazelwood += 1
        if neighborhood == "St. Clair":
            St_Clair += 1
        if neighborhood == "Northview Heights":
            Northview_Heights += 1
        if neighborhood == "Oakwood":
            Oakwood += 1
        if neighborhood == "Arlington":
            Arlington += 1
        if neighborhood == "North Shore":
            North_Shore += 1
        if neighborhood == "Westwood":
            Westwood += 1
        if neighborhood == "Upper Hill":
            Upper_Hill += 1
        if neighborhood == "Polish Hill":
            Polish_Hill += 1
        if neighborhood == "Crawford-Roberts":
            Crawford_Roberts += 1
        if neighborhood == "Lincoln Place":
            Lincoln_Place += 1
        if neighborhood == "Allegheny West":
            Allegheny_West += 1
        if neighborhood == "Larimer":
            Larimer += 1
        if neighborhood == "Glen Hazel":
            Glen_Hazel += 1
        if neighborhood == "Bon Air":
            Bon_Air += 1
        if neighborhood == "Arlington Heights":
            Arlington_Heights += 1
        if neighborhood == "Allentown":
            Allentown += 1
        if neighborhood == "New Homestead":
            New_Homestead += 1
        if neighborhood == "Hays":
            Hays += 1
        if neighborhood == "Central Northside":
            Central_Northside += 1
        if neighborhood == "Stanton Heights":
            Stanton_Heights+= 1
        if neighborhood == "Allegheny Center":
            Allegheny_Center += 1
        if neighborhood == "Friendship":
            Friendship += 1
        if neighborhood == "East Carnegie":
            East_Carnegie += 1
        if neighborhood == "Fairywood":
            Fairywood += 1
        if neighborhood == "Windgap":
            Windgap += 1
        if neighborhood == "Squirrel Hill South":
            Squirrel_Hill_South += 1
        if neighborhood == "Mt. Oliver Neighborhood":
            Mt_Oliver_Neighborhood += 1
        if neighborhood == "Marshall-Shadeland":
            Marshall_Shadeland += 1
        if neighborhood == "Mount Washington":
            Mount_Washington += 1
        if neighborhood == "Summer Hill":
            Summer_Hill += 1
        if neighborhood == "Swisshelm Park":
            Swisshelm_Park += 1
        if neighborhood == "Ridgemont":
            Ridgemont += 1
        if neighborhood == "Outside State":
            Outside_State += 1
        if neighborhood == "Outside County":
            Outside_County += 1
        if neighborhood == "Crafton Heights":
            Crafton_Heights += 1
        if neighborhood == "Troy Hill-Herrs Island":
            Troy_Hill_Herrs_Island += 1
        if neighborhood == "Beechview":
            Beechview += 1
        if neighborhood == "Morningside":
            Morningside += 1
        if neighborhood == "California-Kirkbride":
            California_Kirkbride += 1
        if neighborhood == "Greenfield":
            Greenfield += 1
        if neighborhood == "Bluff":
            Bluff += 1
        if neighborhood == "East Liberty":
            East_Liberty += 1
        if neighborhood == "Elliott":
            Elliott += 1
        if neighborhood == "East Allegheny":
            East_Allegheny += 1
        if neighborhood == "Beltzhoover":
            Beltzhoover += 1
        if neighborhood == "Upper Lawrenceville":
            Upper_Lawrenceville += 1
        if neighborhood == "Sheraden":
            Sheraden += 1
        if neighborhood == "Perry South":
            Perry_South += 1
        if neighborhood == "Manchester":
            Manchester += 1
        if neighborhood == "Strip District":
            Strip_District += 1
        if neighborhood == "Banksville":
            Banksville += 1
        if neighborhood == "Garfield":
            Garfield += 1
        if neighborhood == "Brookline":
            Brookline += 1
        if neighborhood == "South Side Slopes":
            South_Side_Slopes += 1
        if neighborhood == "South Oakland":
            South_Oakland += 1
        if neighborhood == "Spring Hill-City View":
            Spring_Hill_City_View += 1
        if neighborhood == "Terrace Village":
            Terrace_Village += 1
        if neighborhood == "South Shore":
            South_Shore += 1
        if neighborhood == "Chateau":
            Chateau += 1
        if neighborhood == "Duquesne Heights":
            Duquesne_Heights += 1
        if neighborhood == "Overbrook":
            Overbrook += 1
        if neighborhood == "Spring Garden":
            Spring_Garden += 1
        if neighborhood == "West End":
            West_End += 1
        if neighborhood == "Fineview":
            Fineview += 1
        if neighborhood == "Chartiers City":
            Chartiers_City += 1
        if neighborhood == "Esplen":
            Esplen += 1
        if neighborhood == "Mt. Oliver Boro":
            Mt_Oliver_Boro += 1
        if neighborhood == "":
            blank += 1
X = ["Squirrel Hill North","Shadyside","Bedford Dwellings","Lincoln-Lemington-Belmar","Lower Lawrenceville","Central Lawrenceville","Golden Triangle/Civic Arena","Carrick","Highland Park","South Side Flats","Middle Hill","North Oakland","Bloomfield","Outside City","East Hills","Knoxville","Point Breeze","Central Oakland","Brighton Heights","Point Breeze North","Homewood North","Regent Square","Homewood West","Homewood South","Perry North","West Oakland","Hazelwood","St. Clair","Northview Heights","Oakwood","Arlington","North Shore","Westwood","Upper Hill","Polish Hill","Crawford-Roberts","Lincoln Place","Allegheny West","Larimer","Glen Hazel","Bon Air","Arlington Heights","Allentown","New Homestead","Hays","Central Northside","Stanton Heights","Allegheny Center","Friendship","East Carnegie","Fairywood","Windgap","Squirrel Hill South","Mt. Oliver Neighborhood","Marshall-Shadeland","Mount Washington","Summer Hill","Swisshelm Park","Ridgemont","Outside State","Outside County","Crafton Heights","Troy Hill-Herrs Island","Beechview","Morningside","California-Kirkbride","Greenfield","Bluff","East Liberty","Elliott","East Allegheny","Beltzhoover","Upper Lawrenceville","Sheraden","Perry South","Manchester","Strip District","Banksville","Garfield","Brookline","South Side Slopes","South Oakland","Spring Hill-City View","Terrace Village","South Shore","Chateau","Duquesne Heights","Overbrook","Spring Garden","West End","Fineview","Chartiers City","Esplen","Mt. Oliver Boro"]
Y = [Squirrel_Hill_North,   Shadyside,  Bedford_Dwellings,  Lincoln_Lemington_Belmar,  Lower_Lawrenceville,  Central_Lawrenceville,  Golden_Triangle_Civic_Arena,  Carrick,  Highland_Park,  South_Side_Flats,  Middle_Hill,  North_Oakland,  Bloomfield,  Outside_City,  East_Hills,  Knoxville,  Point_Breeze,  Central_Oakland,  Brighton_Heights,  Point_Breeze_North,  Homewood_North,  Regent_Square,  Homewood_West,  Homewood_South,  Perry_North,  West_Oakland,  Hazelwood,  St_Clair,   Northview_Heights,  Oakwood,  Arlington,  North_Shore,  Westwood,  Upper_Hill,  Polish_Hill,  Crawford_Roberts,  Lincoln_Place,  Allegheny_West,  Larimer,  Glen_Hazel,  Bon_Air,  Arlington_Heights,  Allentown,  New_Homestead,  Hays,  Central_Northside,  Stanton_Heights,  Allegheny_Center,  Friendship,  East_Carnegie,  Fairywood,  Windgap,  Squirrel_Hill_South,  Mt_Oliver_Neighborhood,   Marshall_Shadeland,  Mount_Washington,  Summer_Hill,  Swisshelm_Park,  Ridgemont,  Outside_State,  Outside_County,  Crafton_Heights,  Troy_Hill_Herrs_Island,  Beechview,  Morningside,  California_Kirkbride,  Greenfield,  Bluff,  East_Liberty,  Elliott,  East_Allegheny,  Beltzhoover,  Upper_Lawrenceville,  Sheraden,  Perry_South,  Manchester,  Strip_District,  Banksville,  Garfield,  Brookline,  South_Side_Slopes,  South_Oakland,  Spring_Hill_City_View,  Terrace_Village,  South_Shore,  Chateau,  Duquesne_Heights,  Overbrook,  Spring_Garden,  West_End,  Fineview,  Chartiers_City,  Esplen,  Mt_Oliver_Boro]
plt.bar(X, Y, color='g', width=.3) 
plt.title("Police Incidents Over Neighborhoods") 
plt.xlabel("Neighborhoods")
plt.xticks(rotation = 75, fontsize = 3)
plt.ylabel("Number of Incidents")
plt.axhline(y = 5000, color = 'r')
plt.show()

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
Squirrel_Hill_North = 0
Shadyside = 0
Bedford_Dwellings = 0
Lincoln_Lemington_Belmar = 0
Lower_Lawrenceville = 0
Central_Lawrenceville = 0
Golden_Triangle_Civic_Arena = 0
Carrick = 0
Highland_Park = 0
South_Side_Flats = 0
Middle_Hill = 0
North_Oakland = 0
Bloomfield = 0
Outside_City = 0
East_Hills = 0
Knoxville = 0
Point_Breeze = 0
Central_Oakland = 0
Brighton_Heights = 0
Point_Breeze_North = 0
Homewood_North = 0
Regent_Square = 0
Homewood_West = 0
Homewood_South = 0
Perry_North = 0
West_Oakland = 0
Hazelwood = 0
St_Clair = 0
Northview_Heights = 0
Oakwood = 0
Arlington = 0
North_Shore = 0
Westwood = 0
Upper_Hill = 0
Polish_Hill = 0
Crawford_Roberts=0
Lincoln_Place = 0
Allegheny_West = 0
Larimer = 0
Glen_Hazel = 0
Bon_Air = 0
Arlington_Heights = 0
Allentown = 0
New_Homestead = 0
Hays = 0
Central_Northside = 0
Stanton_Heights = 0
Allegheny_Center = 0
Friendship = 0
East_Carnegie = 0
Fairywood = 0
Windgap = 0
Squirrel_Hill_South = 0
Mt_Oliver_Neighborhood = 0
Marshall_Shadeland = 0
Mount_Washington = 0
Summer_Hill = 0
Swisshelm_Park = 0
Ridgemont = 0
Outside_State = 0
Outside_County = 0
Crafton_Heights = 0
Troy_Hill_Herrs_Island = 0
Beechview = 0
Morningside = 0
California_Kirkbride = 0
Greenfield = 0
Bluff = 0
East_Liberty = 0
Elliott = 0
East_Allegheny = 0
Beltzhoover = 0
Upper_Lawrenceville = 0
Sheraden = 0
Perry_South = 0
Manchester = 0
Strip_District = 0
Banksville = 0
Garfield = 0
Brookline = 0
South_Side_Slopes = 0
South_Oakland = 0
Spring_Hill_City_View = 0
Terrace_Village = 0
South_Shore = 0
Chateau = 0
Duquesne_Heights = 0
Overbrook = 0
Spring_Garden = 0
West_End = 0
Fineview = 0
Chartiers_City = 0
Esplen = 0
Mt_Oliver_Boro = 0
blank = 0
with open('C:\\Users\\prest\\Intro-to-Jupyter\\Final-Project\\apb.csv', mode = 'r') as csvfile:
    file = csv.DictReader(csvfile)
    for row in file:
        neighborhood = row['INCIDENTNEIGHBORHOOD']
        if neighborhood == "Squirrel Hill North":
            Squirrel_Hill_North += 1
        if neighborhood == "Shadyside":
            Shadyside += 1
        if neighborhood == "Bedford Dwellings":
            Bedford_Dwellings += 1
        if neighborhood == "Lincoln-Lemington-Belmar":
            Lincoln_Lemington_Belmar += 1
        if neighborhood == "Lower Lawrenceville":
            Lower_Lawrenceville += 1
        if neighborhood == "Central Lawrenceville":
            Central_Lawrenceville += 1
        if neighborhood == "Golden Triangle/Civic Arena":
            Golden_Triangle_Civic_Arena += 1
        if neighborhood == "Carrick":
            Carrick += 1
        if neighborhood == "Highland Park":
            Highland_Park += 1
        if neighborhood == "South Side Flats":
            South_Side_Flats += 1
        if neighborhood == "Middle Hill":
            Middle_Hill += 1
        if neighborhood == "North Oakland":
            North_Oakland += 1
        if neighborhood == "Bloomfield":
            Bloomfield += 1
        if neighborhood == "Outside City":
            Outside_City += 1
        if neighborhood == "East Hills":
            East_Hills += 1
        if neighborhood == "Knoxville":
            Knoxville += 1
        if neighborhood == "Point Breeze":
            Point_Breeze += 1
        if neighborhood == "Central Oakland":
            Central_Oakland += 1
        if neighborhood == "Brighton Heights":
            Brighton_Heights += 1
        if neighborhood == "Point Breeze North":
            Point_Breeze_North += 1
        if neighborhood == "Homewood North":
            Homewood_North += 1
        if neighborhood == "Regent Square":
            Regent_Square += 1
        if neighborhood == "Homewood West":
            Homewood_West += 1
        if neighborhood == "Homewood South":
            Homewood_South += 1
        if neighborhood == "Perry North":
            Perry_North += 1
        if neighborhood == "West Oakland":
            West_Oakland += 1
        if neighborhood == "Hazelwood":
            Hazelwood += 1
        if neighborhood == "St. Clair":
            St_Clair += 1
        if neighborhood == "Northview Heights":
            Northview_Heights += 1
        if neighborhood == "Oakwood":
            Oakwood += 1
        if neighborhood == "Arlington":
            Arlington += 1
        if neighborhood == "North Shore":
            North_Shore += 1
        if neighborhood == "Westwood":
            Westwood += 1
        if neighborhood == "Upper Hill":
            Upper_Hill += 1
        if neighborhood == "Polish Hill":
            Polish_Hill += 1
        if neighborhood == "Crawford-Roberts":
            Crawford_Roberts += 1
        if neighborhood == "Lincoln Place":
            Lincoln_Place += 1
        if neighborhood == "Allegheny West":
            Allegheny_West += 1
        if neighborhood == "Larimer":
            Larimer += 1
        if neighborhood == "Glen Hazel":
            Glen_Hazel += 1
        if neighborhood == "Bon Air":
            Bon_Air += 1
        if neighborhood == "Arlington Heights":
            Arlington_Heights += 1
        if neighborhood == "Allentown":
            Allentown += 1
        if neighborhood == "New Homestead":
            New_Homestead += 1
        if neighborhood == "Hays":
            Hays += 1
        if neighborhood == "Central Northside":
            Central_Northside += 1
        if neighborhood == "Stanton Heights":
            Stanton_Heights+= 1
        if neighborhood == "Allegheny Center":
            Allegheny_Center += 1
        if neighborhood == "Friendship":
            Friendship += 1
        if neighborhood == "East Carnegie":
            East_Carnegie += 1
        if neighborhood == "Fairywood":
            Fairywood += 1
        if neighborhood == "Windgap":
            Windgap += 1
        if neighborhood == "Squirrel Hill South":
            Squirrel_Hill_South += 1
        if neighborhood == "Mt. Oliver Neighborhood":
            Mt_Oliver_Neighborhood += 1
        if neighborhood == "Marshall-Shadeland":
            Marshall_Shadeland += 1
        if neighborhood == "Mount Washington":
            Mount_Washington += 1
        if neighborhood == "Summer Hill":
            Summer_Hill += 1
        if neighborhood == "Swisshelm Park":
            Swisshelm_Park += 1
        if neighborhood == "Ridgemont":
            Ridgemont += 1
        if neighborhood == "Outside State":
            Outside_State += 1
        if neighborhood == "Outside County":
            Outside_County += 1
        if neighborhood == "Crafton Heights":
            Crafton_Heights += 1
        if neighborhood == "Troy Hill-Herrs Island":
            Troy_Hill_Herrs_Island += 1
        if neighborhood == "Beechview":
            Beechview += 1
        if neighborhood == "Morningside":
            Morningside += 1
        if neighborhood == "California-Kirkbride":
            California_Kirkbride += 1
        if neighborhood == "Greenfield":
            Greenfield += 1
        if neighborhood == "Bluff":
            Bluff += 1
        if neighborhood == "East Liberty":
            East_Liberty += 1
        if neighborhood == "Elliott":
            Elliott += 1
        if neighborhood == "East Allegheny":
            East_Allegheny += 1
        if neighborhood == "Beltzhoover":
            Beltzhoover += 1
        if neighborhood == "Upper Lawrenceville":
            Upper_Lawrenceville += 1
        if neighborhood == "Sheraden":
            Sheraden += 1
        if neighborhood == "Perry South":
            Perry_South += 1
        if neighborhood == "Manchester":
            Manchester += 1
        if neighborhood == "Strip District":
            Strip_District += 1
        if neighborhood == "Banksville":
            Banksville += 1
        if neighborhood == "Garfield":
            Garfield += 1
        if neighborhood == "Brookline":
            Brookline += 1
        if neighborhood == "South Side Slopes":
            South_Side_Slopes += 1
        if neighborhood == "South Oakland":
            South_Oakland += 1
        if neighborhood == "Spring Hill-City View":
            Spring_Hill_City_View += 1
        if neighborhood == "Terrace Village":
            Terrace_Village += 1
        if neighborhood == "South Shore":
            South_Shore += 1
        if neighborhood == "Chateau":
            Chateau += 1
        if neighborhood == "Duquesne Heights":
            Duquesne_Heights += 1
        if neighborhood == "Overbrook":
            Overbrook += 1
        if neighborhood == "Spring Garden":
            Spring_Garden += 1
        if neighborhood == "West End":
            West_End += 1
        if neighborhood == "Fineview":
            Fineview += 1
        if neighborhood == "Chartiers City":
            Chartiers_City += 1
        if neighborhood == "Esplen":
            Esplen += 1
        if neighborhood == "Mt. Oliver Boro":
            Mt_Oliver_Boro += 1
        if neighborhood == "":
            blank += 1
X = ["Bedford Dwellings","Lower Lawrenceville","Outside City","Point Breeze","Point Breeze North","Regent Square","Homewood West","West Oakland","St. Clair","Northview Heights","Oakwood","Arlington","North Shore","Westwood","Upper Hill","Polish Hill","Crawford-Roberts","Lincoln Place","Allegheny West","Glen Hazel","Bon Air","Arlington Heights","New Homestead","Hays","Stanton Heights","Allegheny Center","Friendship","East Carnegie","Fairywood","Windgap","Mt. Oliver Neighborhood","Summer Hill","Swisshelm Park","Ridgemont","Outside State","Outside County","Crafton Heights","Troy Hill-Herrs Island","Morningside","California-Kirkbride","Greenfield","Bluff","Elliott","Beltzhoover","Upper Lawrenceville","Manchester","Banksville","South Oakland","Spring Hill-City View","Terrace Village","South Shore","Chateau","Duquesne Heights","Overbrook","Spring Garden","West End","Fineview","Chartiers City","Esplen","Mt. Oliver Boro"]
Y = [ Bedford_Dwellings,  Lower_Lawrenceville,  Outside_City,  Point_Breeze,  Point_Breeze_North,  Regent_Square,  Homewood_West,  West_Oakland,  St_Clair,   Northview_Heights,  Oakwood,  Arlington,  North_Shore,  Westwood,  Upper_Hill,  Polish_Hill,  Crawford_Roberts,  Lincoln_Place,  Allegheny_West,  Glen_Hazel,  Bon_Air,  Arlington_Heights,  New_Homestead,  Hays,  Stanton_Heights,  Allegheny_Center,  Friendship,  East_Carnegie,  Fairywood,  Windgap,  Mt_Oliver_Neighborhood,  Summer_Hill,  Swisshelm_Park,  Ridgemont,  Outside_State,  Outside_County,  Crafton_Heights,  Troy_Hill_Herrs_Island,  Morningside,  California_Kirkbride,  Greenfield,  Bluff,  Elliott,  Beltzhoover,  Upper_Lawrenceville,  Manchester,  Banksville,  South_Oakland,  Spring_Hill_City_View,  Terrace_Village,  South_Shore,  Chateau,  Duquesne_Heights,  Overbrook,  Spring_Garden,  West_End,  Fineview,  Chartiers_City,  Esplen,  Mt_Oliver_Boro]
print(Y)
plt.bar(X, Y, color='g') 
plt.title("Police Incidents(Under 5000) Over Neighborhoods") 
plt.xlabel("Neighborhoods")
plt.xticks(rotation = 85, fontsize = 5)
plt.ylabel("Number of Incidents")
plt.show()
# Out:
# [2722, 4949, 4167, 4549, 3779, 952, 4009, 3617, 2001, 4130, 904, 3445, 4732, 2907, 2968, 1466, 4887, 2566, 2161, 947, 1668, 902, 459, 875, 2848, 4801, 3170, 734, 1058, 1357, 852, 784, 616, 817, 202, 201, 3865, 3670, 1978, 2348, 4553, 5000, 3586, 3134, 3328, 3173, 2354, 2998, 3154, 3534, 2970, 2356, 1583, 2865, 1312, 1560, 2549, 427, 1050, 239]

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
Squirrel_Hill_North = 0
Shadyside = 0
Bedford_Dwellings = 0
Lincoln_Lemington_Belmar = 0
Lower_Lawrenceville = 0
Central_Lawrenceville = 0
Golden_Triangle_Civic_Arena = 0
Carrick = 0
Highland_Park = 0
South_Side_Flats = 0
Middle_Hill = 0
North_Oakland = 0
Bloomfield = 0
Outside_City = 0
East_Hills = 0
Knoxville = 0
Point_Breeze = 0
Central_Oakland = 0
Brighton_Heights = 0
Point_Breeze_North = 0
Homewood_North = 0
Regent_Square = 0
Homewood_West = 0
Homewood_South = 0
Perry_North = 0
West_Oakland = 0
Hazelwood = 0
St_Clair = 0
Northview_Heights = 0
Oakwood = 0
Arlington = 0
North_Shore = 0
Westwood = 0
Upper_Hill = 0
Polish_Hill = 0
Crawford_Roberts=0
Lincoln_Place = 0
Allegheny_West = 0
Larimer = 0
Glen_Hazel = 0
Bon_Air = 0
Arlington_Heights = 0
Allentown = 0
New_Homestead = 0
Hays = 0
Central_Northside = 0
Stanton_Heights = 0
Allegheny_Center = 0
Friendship = 0
East_Carnegie = 0
Fairywood = 0
Windgap = 0
Squirrel_Hill_South = 0
Mt_Oliver_Neighborhood = 0
Marshall_Shadeland = 0
Mount_Washington = 0
Summer_Hill = 0
Swisshelm_Park = 0
Ridgemont = 0
Outside_State = 0
Outside_County = 0
Crafton_Heights = 0
Troy_Hill_Herrs_Island = 0
Beechview = 0
Morningside = 0
California_Kirkbride = 0
Greenfield = 0
Bluff = 0
East_Liberty = 0
Elliott = 0
East_Allegheny = 0
Beltzhoover = 0
Upper_Lawrenceville = 0
Sheraden = 0
Perry_South = 0
Manchester = 0
Strip_District = 0
Banksville = 0
Garfield = 0
Brookline = 0
South_Side_Slopes = 0
South_Oakland = 0
Spring_Hill_City_View = 0
Terrace_Village = 0
South_Shore = 0
Chateau = 0
Duquesne_Heights = 0
Overbrook = 0
Spring_Garden = 0
West_End = 0
Fineview = 0
Chartiers_City = 0
Esplen = 0
Mt_Oliver_Boro = 0
blank = 0
with open('C:\\Users\\prest\\Intro-to-Jupyter\\Final-Project\\apb.csv', mode = 'r') as csvfile:
    file = csv.DictReader(csvfile)
    for row in file:
        neighborhood = row['INCIDENTNEIGHBORHOOD']
        if neighborhood == "Squirrel Hill North":
            Squirrel_Hill_North += 1
        if neighborhood == "Shadyside":
            Shadyside += 1
        if neighborhood == "Bedford Dwellings":
            Bedford_Dwellings += 1
        if neighborhood == "Lincoln-Lemington-Belmar":
            Lincoln_Lemington_Belmar += 1
        if neighborhood == "Lower Lawrenceville":
            Lower_Lawrenceville += 1
        if neighborhood == "Central Lawrenceville":
            Central_Lawrenceville += 1
        if neighborhood == "Golden Triangle/Civic Arena":
            Golden_Triangle_Civic_Arena += 1
        if neighborhood == "Carrick":
            Carrick += 1
        if neighborhood == "Highland Park":
            Highland_Park += 1
        if neighborhood == "South Side Flats":
            South_Side_Flats += 1
        if neighborhood == "Middle Hill":
            Middle_Hill += 1
        if neighborhood == "North Oakland":
            North_Oakland += 1
        if neighborhood == "Bloomfield":
            Bloomfield += 1
        if neighborhood == "Outside City":
            Outside_City += 1
        if neighborhood == "East Hills":
            East_Hills += 1
        if neighborhood == "Knoxville":
            Knoxville += 1
        if neighborhood == "Point Breeze":
            Point_Breeze += 1
        if neighborhood == "Central Oakland":
            Central_Oakland += 1
        if neighborhood == "Brighton Heights":
            Brighton_Heights += 1
        if neighborhood == "Point Breeze North":
            Point_Breeze_North += 1
        if neighborhood == "Homewood North":
            Homewood_North += 1
        if neighborhood == "Regent Square":
            Regent_Square += 1
        if neighborhood == "Homewood West":
            Homewood_West += 1
        if neighborhood == "Homewood South":
            Homewood_South += 1
        if neighborhood == "Perry North":
            Perry_North += 1
        if neighborhood == "West Oakland":
            West_Oakland += 1
        if neighborhood == "Hazelwood":
            Hazelwood += 1
        if neighborhood == "St. Clair":
            St_Clair += 1
        if neighborhood == "Northview Heights":
            Northview_Heights += 1
        if neighborhood == "Oakwood":
            Oakwood += 1
        if neighborhood == "Arlington":
            Arlington += 1
        if neighborhood == "North Shore":
            North_Shore += 1
        if neighborhood == "Westwood":
            Westwood += 1
        if neighborhood == "Upper Hill":
            Upper_Hill += 1
        if neighborhood == "Polish Hill":
            Polish_Hill += 1
        if neighborhood == "Crawford-Roberts":
            Crawford_Roberts += 1
        if neighborhood == "Lincoln Place":
            Lincoln_Place += 1
        if neighborhood == "Allegheny West":
            Allegheny_West += 1
        if neighborhood == "Larimer":
            Larimer += 1
        if neighborhood == "Glen Hazel":
            Glen_Hazel += 1
        if neighborhood == "Bon Air":
            Bon_Air += 1
        if neighborhood == "Arlington Heights":
            Arlington_Heights += 1
        if neighborhood == "Allentown":
            Allentown += 1
        if neighborhood == "New Homestead":
            New_Homestead += 1
        if neighborhood == "Hays":
            Hays += 1
        if neighborhood == "Central Northside":
            Central_Northside += 1
        if neighborhood == "Stanton Heights":
            Stanton_Heights+= 1
        if neighborhood == "Allegheny Center":
            Allegheny_Center += 1
        if neighborhood == "Friendship":
            Friendship += 1
        if neighborhood == "East Carnegie":
            East_Carnegie += 1
        if neighborhood == "Fairywood":
            Fairywood += 1
        if neighborhood == "Windgap":
            Windgap += 1
        if neighborhood == "Squirrel Hill South":
            Squirrel_Hill_South += 1
        if neighborhood == "Mt. Oliver Neighborhood":
            Mt_Oliver_Neighborhood += 1
        if neighborhood == "Marshall-Shadeland":
            Marshall_Shadeland += 1
        if neighborhood == "Mount Washington":
            Mount_Washington += 1
        if neighborhood == "Summer Hill":
            Summer_Hill += 1
        if neighborhood == "Swisshelm Park":
            Swisshelm_Park += 1
        if neighborhood == "Ridgemont":
            Ridgemont += 1
        if neighborhood == "Outside State":
            Outside_State += 1
        if neighborhood == "Outside County":
            Outside_County += 1
        if neighborhood == "Crafton Heights":
            Crafton_Heights += 1
        if neighborhood == "Troy Hill-Herrs Island":
            Troy_Hill_Herrs_Island += 1
        if neighborhood == "Beechview":
            Beechview += 1
        if neighborhood == "Morningside":
            Morningside += 1
        if neighborhood == "California-Kirkbride":
            California_Kirkbride += 1
        if neighborhood == "Greenfield":
            Greenfield += 1
        if neighborhood == "Bluff":
            Bluff += 1
        if neighborhood == "East Liberty":
            East_Liberty += 1
        if neighborhood == "Elliott":
            Elliott += 1
        if neighborhood == "East Allegheny":
            East_Allegheny += 1
        if neighborhood == "Beltzhoover":
            Beltzhoover += 1
        if neighborhood == "Upper Lawrenceville":
            Upper_Lawrenceville += 1
        if neighborhood == "Sheraden":
            Sheraden += 1
        if neighborhood == "Perry South":
            Perry_South += 1
        if neighborhood == "Manchester":
            Manchester += 1
        if neighborhood == "Strip District":
            Strip_District += 1
        if neighborhood == "Banksville":
            Banksville += 1
        if neighborhood == "Garfield":
            Garfield += 1
        if neighborhood == "Brookline":
            Brookline += 1
        if neighborhood == "South Side Slopes":
            South_Side_Slopes += 1
        if neighborhood == "South Oakland":
            South_Oakland += 1
        if neighborhood == "Spring Hill-City View":
            Spring_Hill_City_View += 1
        if neighborhood == "Terrace Village":
            Terrace_Village += 1
        if neighborhood == "South Shore":
            South_Shore += 1
        if neighborhood == "Chateau":
            Chateau += 1
        if neighborhood == "Duquesne Heights":
            Duquesne_Heights += 1
        if neighborhood == "Overbrook":
            Overbrook += 1
        if neighborhood == "Spring Garden":
            Spring_Garden += 1
        if neighborhood == "West End":
            West_End += 1
        if neighborhood == "Fineview":
            Fineview += 1
        if neighborhood == "Chartiers City":
            Chartiers_City += 1
        if neighborhood == "Esplen":
            Esplen += 1
        if neighborhood == "Mt. Oliver Boro":
            Mt_Oliver_Boro += 1
        if neighborhood == "":
            blank += 1
X = ["Regent Square","Oakwood","Glen Hazel","Arlington Heights","New Homestead","Hays","East Carnegie","Mt. Oliver Neighborhood","Summer Hill","Swisshelm Park","Ridgemont","Outside State","Outside County","Chartiers City","Mt. Oliver Boro"]
Y = [ Regent_Square,  Oakwood,  Glen_Hazel,  Arlington_Heights,  New_Homestead,  Hays,  East_Carnegie,  Mt_Oliver_Neighborhood,   Summer_Hill,  Swisshelm_Park,  Ridgemont,  Outside_State,  Outside_County,  Chartiers_City,  Mt_Oliver_Boro]
colors = ['g','g','g','g','tan','g','g','g','g','g','g','c','c','silver','gold']
plt.bar(X, Y, color=colors) 
plt.title("Police Incidents(Under 1000) Over Neighborhoods") 
plt.xlabel("Neighborhoods")
plt.xticks(rotation = 85, fontsize = 10)
plt.ylabel("Number of Incidents")
plt.show()
